# %% [markdown]
# # **LAB ASSIGNMENT - 5**

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
documents = [
    "The quick brown fox jumps over the lazy dog",
    "Never jump over the lazy dog quickly",
    "A quick brown dog outpaces a quick fox"
]

doc_names = ["d1", "d2", "d3"]

print("Documents:")
for i, doc in enumerate(documents):
    print(doc_names[i], ":", doc)
# Out:
# Documents:
# d1 : The quick brown fox jumps over the lazy dog
# d2 : Never jump over the lazy dog quickly
# d3 : A quick brown dog outpaces a quick fox

# %%
user_query = input("Enter your search query: ")

query = [user_query]

print("User Query:", query[0])
# Out:
# Enter your search query: quick dog
# User Query: quick dog

# %%
all_text = documents + query

print("Combined Text Data:")
print(all_text)
# Out:
# Combined Text Data:
# ['The quick brown fox jumps over the lazy dog', 'Never jump over the lazy dog quickly', 'A quick brown dog outpaces a quick fox', 'quick dog']

# %%
vectorizer = TfidfVectorizer(stop_words='english')

tfidf_matrix = vectorizer.fit_transform(all_text)

print("TF-IDF Matrix Shape:", tfidf_matrix.shape)
# Out:
# TF-IDF Matrix Shape: (4, 9)

# %%
doc_vectors = tfidf_matrix[:-1]
query_vector = tfidf_matrix[-1]

print("Document Vectors Shape:", doc_vectors.shape)
print("Query Vector Shape:", query_vector.shape)
# Out:
# Document Vectors Shape: (3, 9)
# Query Vector Shape: (1, 9)

# %%
similarity_scores = cosine_similarity(doc_vectors, query_vector)

similarity_scores = similarity_scores.flatten()

print("Cosine Similarity Scores:")

for i in range(len(doc_names)):
    print(doc_names[i], ":", similarity_scores[i])
# Out:
# Cosine Similarity Scores:
# d1 : 0.4379151303123337
# d2 : 0.19416311776476333
# d3 : 0.6476605284217921

# %%
ranking = sorted(zip(doc_names, similarity_scores),
                 key=lambda x: x[1],
                 reverse=True)

print("\nDocument Ranking:")

for i, (doc, score) in enumerate(ranking, start=1):
    print(i, ".", doc, "->", score)
# Out:
# Document Ranking:
# 1 . d3 -> 0.6476605284217921
# 2 . d1 -> 0.4379151303123337
# 3 . d2 -> 0.19416311776476333

# %%
true_labels = [1, 0, 1]

print("True Labels:", true_labels)
# Out:
# True Labels: [1, 0, 1]

# %%
predicted_labels = []

for score in similarity_scores:
    if score > 0:
        predicted_labels.append(1)
    else:
        predicted_labels.append(0)

print("Predicted Labels:", predicted_labels)
# Out:
# Predicted Labels: [1, 1, 1]

# %%
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print("\nEvaluation Metrics")

print("Precision:", precision)
print("Recall:", recall)
print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Evaluation Metrics
# Precision: 0.6666666666666666
# Recall: 1.0
# Accuracy: 0.6666666666666666
# F1 Score: 0.8
